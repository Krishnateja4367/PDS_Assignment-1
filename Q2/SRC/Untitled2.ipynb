# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw=pd.read_csv('StudentsPerformance.csv')

# %%
raw
# Out:
#      Unnamed: 0  gender race/ethnicity parental level of education  \
# 0             0  female        group B           bachelor's degree
# 1             1  female        group C                some college
# 2             2  female        group B             master's degree
# 3             3    male        group A          associate's degree
# 4             4    male        group C                some college
# ..          ...     ...            ...                         ...
# 995         995  female        group E             master's degree
# 996         996    male        group C                 high school
# 997         997  female        group C                 high school
# 998         998  female        group D                some college
# 999         999  female        group D                some college
#
#             lunch  test preparation course  math score  reading score  \
# 0        standard                        0         146             72
# ...

# %%
palette = {'group A': 'blue', 'group B': 'green', 'group C': 'orange', 'group D': 'red', 'group E': 'purple'}

plt.figure(figsize=(10,6))
sns.violinplot(x='race/ethnicity', y='reading score', data=raw, palette=palette)
plt.title('Reading Score Distribution by Race/Ethnicity')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.pairplot(raw[['math score', 'reading score', 'writing score']])
plt.title('Pairwise Relationships between Scores')
plt.show()

# %%
plt.figure(figsize=(10,6))
correlation_matrix = raw[['math score', 'reading score', 'writing score']].corr()
sns.heatmap(data=correlation_matrix, annot=True)
plt.title('Correlation between Scores')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(raw['writing score'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Writing Scores')
plt.xlabel('Writing Score')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(raw['math score'], raw['reading score'], alpha=0.5)
plt.title('Math vs Reading Scores')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.show()
